# %% [markdown]
# <a href="https://colab.research.google.com/github/avvyy05/avvyy05/blob/main/Avani_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
pd.read_excel('python.xlsx')
# Out:
#   Unnamed: 0      city      country  math   science
# 0      prina    london           uk    67        87
# 1     aakshi        NY          usa    80        79
# 2      avani  Auckland  New zealand    78        80
# 3       jiya        UK           uk    69        93
# 4      avani       USA          usa    75        81

# %%
pd.read_excel('python.xlsx',index_col=0)
# Out:
#             city      country  math   science
# prina     london           uk    67        87
# aakshi        NY          usa    80        79
# avani   Auckland  New zealand    78        80
# jiya          UK           uk    69        93
# avani        USA          usa    75        81

# %%
pd.read_excel('python.xlsx',index_col=0,header=1)
# Out:
#           london           uk  67  87
# prina
# aakshi        NY          usa  80  79
# avani   Auckland  New zealand  78  80
# jiya          UK           uk  69  93
# avani        USA          usa  75  81

# %%
pd.read_excel('python.xlsx',index_col=0,usecols='A:C')
# Out:
#             city      country
# prina     london           uk
# aakshi        NY          usa
# avani   Auckland  New zealand
# jiya          UK           uk
# avani        USA          usa

# %%
pd.read_excel('python.xlsx',index_col=0,usecols='A:C',names=["name","place","desh"])
# Out:
#            place         desh
# name
# prina     london           uk
# aakshi        NY          usa
# avani   Auckland  New zealand
# jiya          UK           uk
# avani        USA          usa

# %%
pd.read_excel('python.xlsx',index_col=0,usecols=[0,2,3])
# Out:
#             country  math
# prina            uk    67
# aakshi          usa    80
# avani   New zealand    78
# jiya             uk    69
# avani           usa    75

# %%
pd.read_excel('python.xlsx',index_col=0,header=0,usecols=[0,1,2],sheet_name=1)
# Out:
#          city      country
# abc    london           uk
# xyz        NY          usa
# pqr  Auckland  New zealand
# uvw        UK           uk

# %%
import pandas as pd
pd.read_excel('python.xlsx',index_col=0,header=0,usecols=[0,1,2],sheet_name='teacher')
# Out:
#          city      country
# abc    london           uk
# xyz        NY          usa
# pqr  Auckland  New zealand
# uvw        UK           uk

# %%
pd.read_excel('python.xlsx',index_col=0,header=0,usecols=[0,1,2],sheet_name=1,skiprows=[0,1])
# Out:
#            NY          usa
# xyz
# pqr  Auckland  New zealand
# uvw        UK           uk

# %%
teacher = pd.read_excel('python.xlsx',index_col=0,header=0,usecols=[0,1,2],sheet_name=1)
print(teacher)
# Out:
#          city      country
# abc    london           uk
# xyz        NY          usa
# pqr  Auckland  New zealand
# uvw        UK           uk

# %%
teacher
# Out:
#          city      country
# abc    london           uk
# xyz        NY          usa
# pqr  Auckland  New zealand
# uvw        UK           uk

# %%
teacher.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, abc to uvw
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   city     4 non-null      object
#  1   country  4 non-null      object
# dtypes: object(2)
# memory usage: 96.0+ bytes

# %%
teacher.head()
# head() function displays first few rows and tail() displays last few rows
# Out:
#          city      country
# abc    london           uk
# xyz        NY          usa
# pqr  Auckland  New zealand
# uvw        UK           uk

# %%
teacher.to_csv("newCSV.csv")

# %%
import pandas as pd
teacher = pd.read_excel('python.xlsx',index_col=0,header=0,usecols=[0,1,2],sheet_name=1)
print(teacher)
# Out:
#          city      country
# a      london           uk
# b          NY          usa
# c    Auckland  New zealand
# d          UK           uk
# e       delhi        india
# f          LA          usa
# g    Auckland  New zealand
# h  Birmingham           uk
# i      london           uk
# j        ohio          usa
# k      london        paris
# l   santorini       greece
# m      london           uk
# n          NY          usa

# %%
teacher.head(n=4)
# Out:
#        city      country
# a    london           uk
# b        NY          usa
# c  Auckland  New zealand
# d        UK           uk

# %%
import cv2

# %%
import numpy as np

# %%
from google.colab.patches import cv2_imshow

# %%
i = cv2.imread('cat.jpeg')

# %%
cv2_imshow(i)
#cv2.waitkey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
gray = cv2.cvtColor(i,cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
#BGR image
ib = i[:,:,0]  # the first page B matrix
ig = i[:,:,1]  # second page G matrix
ir = i[:,:,2]  # third page R matrix
all3 = np.hstack((ib,ig,ir))
cv2_imshow(all3)
# Out:
# <PIL.Image.Image image mode=L size=825x183>

# %%
i = cv2.imread('cat.jpeg')
temp = i
temp[:,:,0]=0
cv2_imshow(i)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
i = cv2.imread('cat.jpeg')
resizeimg = cv2.resize(gray,(256,256))
cv2_imshow(resizeimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
resizeimg = cv2.resize(gray,(256,256))
cv2_imshow(resizeimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
print(gray.shape)
# Out:
# (183, 275)

# %%
gflip = cv2.flip(gray,1) #0,1,-1
cv2_imshow(gflip)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
gflip = cv2.flip(gray,0) #0,1,-1
cv2_imshow(gflip)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
gflip = cv2.flip(gray,-1) #0,1,-1
cv2_imshow(gflip)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
gflip = cv2.flip(resizeimg,0) #0,1,-1
cv2_imshow(gflip)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
gcrop = gray[100:200,200:350]
cv2_imshow(gcrop)
# Out:
# <PIL.Image.Image image mode=L size=75x83>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def sharpen_image(image):
    kernel = np.array([[-1, -1, -1],
                       [-1, 12, -1],
                       [-1, -1, -1]])
    return cv2.filter2D(image, -1, kernel)

image = cv2.imread('cat.jpeg')
sharpened_image = sharpen_image(image)
original_and_sharpened_image = np.hstack((image, sharpened_image))
plt.figure(figsize = [30, 30])
plt.axis('off')
plt.imshow(original_and_sharpened_image[:,:,::-1])

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# Reading image from folder where it is stored
img = cv2.imread('cat.jpeg')

# denoising of image saving it into dst image
dst = cv2.fastNlMeansDenoisingColored(img, None, 10, 10, 7, 15)

# Plotting of source and destination image
plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(dst)

plt.show()

# %%
pip install image_dehazer

# %%
import image_dehazer										# Load the library

HazeImg = cv2.imread('image_path')						# read input image -- (**must be a color image**)
HazeCorrectedImg, HazeTransmissionMap = image_dehazer.remove_haze(HazeImg)		# Remove Haze

cv2.imshow('input image', HazeImg);						# display the original hazy image
cv2.imshow('enhanced_image', HazeCorrectedImg);			# display the result
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-94-17ded1dd6c3c> in <cell line: 4>()
#       2
#       3 HazeImg = cv2.imread('cat.jpeg')                                                # read input image -- **must be a color image**
# ----> 4 HazeCorrectedImg, HazeMap = image_dehazer.remove_haze(HazeImg)          # Remove Haze
#       5
#       6 cv2.imshow('input image', HazeImg);                                             # display the original hazy image
#
# /usr/local/lib/python3.10/dist-packages/image_dehazer/__init__.py in remove_haze(HazeImg, airlightEstimation_windowSze, boundaryConstraint_windowSze, C0, C1, regularize_lambda, sigma, delta, showHazeTransmissionMap)
#     299                             regularize_lambda=regularize_lambda, sigma=sigma, delta=delta,
#     300                             showHazeTransmissionMap=showHazeTransmissionMap)
# ...

# %%
tf = open('textfile.txt')
text = tf.read()
print(text)
# Out:
# A quick brown fox jumped over the lazy dog. Dogs are friendly animals.

# %%
import nltk
nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# ...

# %%
import nltk
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# ...

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
st = sent_tokenize(text.lower())
print(st)
# Out:
# ['a quick brown fox jumped over the lazy dog.', 'dogs are friendly animals.']

# %%
wt = word_tokenize(text.lower())
print(wt)
# Out:
# ['a', 'quick', 'brown', 'fox', 'jumped', 'over', 'the', 'lazy', 'dog', '.', 'dogs', 'are', 'friendly', 'animals', '.']

# %%
from nltk.probability import FreqDist
fdist = FreqDist(wt)
fdist.most_common()
# Out:
# [('.', 2),
#  ('a', 1),
#  ('quick', 1),
#  ('brown', 1),
#  ('fox', 1),
#  ('jumped', 1),
#  ('over', 1),
#  ('the', 1),
#  ('lazy', 1),
#  ('dog', 1),
#  ('dogs', 1),
#  ('are', 1),
#  ('friendly', 1),
#  ('animals', 1)]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Read from a .txt file
with open("textfile.txt", "r", encoding="utf-8") as file:
    text = file.read()

# Generate WordCloud
wordcloud = WordCloud(width=800, height=800,
                      background_color='black',
                      stopwords=stopwords,
                      min_font_size=15).generate(comment_words)

# Plot the WordCloud image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()

# %%
from string import punctuation
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
"nlp"=="nlp."
# Out:
# False

# %%
tc = "".join([char for char in text if char not in punctuation])
print(tc)
# Out:
# A quick brown fox jumped over the lazy dog Dogs are friendly animals

# %%
tc = [char for char in text if char not in punctuation]
print(tc)
# Out:
# ['A', ' ', 'q', 'u', 'i', 'c', 'k', ' ', 'b', 'r', 'o', 'w', 'n', ' ', 'f', 'o', 'x', ' ', 'j', 'u', 'm', 'p', 'e', 'd', ' ', 'o', 'v', 'e', 'r', ' ', 't', 'h', 'e', ' ', 'l', 'a', 'z', 'y', ' ', 'd', 'o', 'g', ' ', 'D', 'o', 'g', 's', ' ', 'a', 'r', 'e', ' ', 'f', 'r', 'i', 'e', 'n', 'd', 'l', 'y', ' ', 'a', 'n', 'i', 'm', 'a', 'l', 's']

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words("english")
#print(stopwords)
nostop = [char for char in wt if char not in stopwords]
print(nostop)
# Out:
# ['quick', 'brown', 'fox', 'jumped', 'lazy', 'dog', '.', 'dogs', 'friendly', 'animals', '.']

# %%
#function
def clean_text(text):
     text = "".join([char for char in text if char not in punctuation])
     tokens = word_tokenize(text.lower())
     #print(tokens)
     nostop = [char for char in tokens if char not in stopwords]
     return nostop

print(clean_text(text))
print(clean_text("i love myself !!"))
# Out:
# ['quick', 'brown', 'fox', 'jumped', 'lazy', 'dog', 'dogs', 'friendly', 'animals']
# ['love']
