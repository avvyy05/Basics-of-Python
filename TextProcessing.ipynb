# %% [markdown]
# <a href="https://colab.research.google.com/github/avvyy05/avvyy05/blob/main/TextProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.youtube.com/watch?v=Y1GAHy2UTWc

# %%
tf = open('textfile.txt')
text = tf.read()
print(text)
# Out:
# A quick brown fox jumped over the lazy dog. Dogs are friendly animals. This is another sentence.

# %%
import nltk
nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# ...

# %%
from nltk.tokenize import sent_tokenize
st = sent_tokenize(text.lower())
print(st)
# Out:
# ['a quick brown fox jumped over the lazy dog.', 'dogs are friendly animals.', 'this is another sentence.']

# %%
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt

# %%
tf = open('textfile.txt')
text = tf.read()
wordcloud = WordCloud(width=800,height=800,background_color='WHITE').generate(text)
plt.figure(figsize=(10,8))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from nltk.tokenize import word_tokenize
wt = word_tokenize(text.lower())
print(wt)
# Out:
# ['a', 'quick', 'brown', 'fox', 'jumped', 'over', 'the', 'lazy', 'dog', '.', 'dogs', 'are', 'friendly', 'animals', '.', 'this', 'is', 'another', 'sentence', '.']

# %%
from nltk.probability import FreqDist
fdist = FreqDist(wt)
fdist.most_common(3)
# Out:
# [('.', 3), ('a', 1), ('quick', 1)]

# %%
from string import punctuation
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
"nlp"=="nlp."

# %%
tc = "".join([char for char in text if char not in punctuation])
print(tc)
# Out:
# A quick brown fox jumped over the lazy dog Dogs are friendly animals This is another sentence

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words("english")
#print(stopwords)
nostop = [word for word in wt if word not in stopwords]
print(nostop)
# Out:
# ['quick', 'brown', 'fox', 'jumped', 'lazy', 'dog', '.', 'dogs', 'friendly', 'animals', '.', 'another', 'sentence', '.']

# %%
#function
def clean_text(text):
     text = "".join([char for char in text if char not in punctuation])
     tokens = word_tokenize(text.lower())
     #print(tokens)
     nostop = [char for char in tokens if char not in stopwords]
     return

print(clean_text(text))
print(clean_text("i love nlp, today is friday. day is hot!!!"))
# Out:
# ['quick', 'brown', 'fox', 'jumped', 'lazy', 'dog', 'dogs', 'friendly', 'animals', 'another', 'sentence']
# ['love', 'nlp', 'today', 'friday', 'day', 'hot']
