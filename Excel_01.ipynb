# %% [markdown]
# <a href="https://colab.research.google.com/github/avvyy05/avvyy05/blob/main/Excel_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# :Reference:
# https://www.youtube.com/watch?v=hT4b9vFZRB0
#
# **pandas vs openpyxl**
# pandas is simpler and openpyxl is advanced for formatting etc. functions with excel

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
pd.read_excel('exl.xlsx')
# Out:
#   Unnamed: 0         City      Country  Math  Science
# 0      Prina       London           UK    67       87
# 1     Aakshi           NY          USA    80       79
# 2      Avani     Auckland  New Zealand    78       80
# 3       Jiya   New Castle           UK    69       93
# 4      Avani  Los Angeles          USA    75       81

# %%
pd.read_excel('exl.xlsx',index_col=0)
# Out:
#                City      Country  Math  Science
# Prina        London           UK    67       87
# Aakshi           NY          USA    80       79
# Avani      Auckland  New Zealand    78       80
# Jiya     New Castle           UK    69       93
# Avani   Los Angeles          USA    75       81

# %%
h3 = pd.read_excel('exl.xlsx')
h3 = h3.head(3)
print(h3)
# Out:
#   Unnamed: 0      City      Country  Math  Science
# 0      Prina    London           UK    67       87
# 1     Aakshi        NY          USA    80       79
# 2      Avani  Auckland  New Zealand    78       80

# %%
pd.read_excel('exl.xlsx',index_col=0,header=0)
# Out:
#                City      Country  Math  Science
# Prina        London           UK    67       87
# Aakshi           NY          USA    80       79
# Avani      Auckland  New Zealand    78       80
# Jiya     New Castle           UK    69       93
# Avani   Los Angeles          USA    75       81

# %%
pd.read_excel('exl.xlsx',index_col=0,usecols='A:C')
# Out:
#                City      Country
# Prina        London           UK
# Aakshi           NY          USA
# Avani      Auckland  New Zealand
# Jiya     New Castle           UK
# Avani   Los Angeles          USA

# %%
pd.read_excel('exl.xlsx',index_col=0,usecols='A:C',names=["name","place","desh"])
# Out:
#               place         desh
# name
# Prina        London           UK
# Aakshi           NY          USA
# Avani      Auckland  New Zealand
# Jiya     New Castle           UK
# Avani   Los Angeles          USA

# %%
pd.read_excel('exl.xlsx',index_col=0,usecols=[0,2,3])
# Out:
#             Country  Math
# Prina            UK    67
# Aakshi          USA    80
# Avani   New Zealand    78
# Jiya             UK    69
# Avani           USA    75

# %%
pd.read_excel('exl.xlsx',index_col=0,header=0,usecols=[0,1,2],sheet_name=1)
# Out:
#              City    Country
# Rahul      Mumbai      India
# John      Columbo  Sri Lanka
# Mandy     Canbera  Australia
# Parry     Toronto     Canada
# Tom    New Jersey        USA

# %%
pd.read_excel('exl.xlsx',index_col=0,header=0,usecols=[0,1,2],sheet_name='teacher')
# Out:
#              City    Country
# Rahul      Mumbai      India
# John      Columbo  Sri Lanka
# Mandy     Canbera  Australia
# Parry     Toronto     Canada
# Tom    New Jersey        USA

# %%
pd.read_excel('exl.xlsx',index_col=0,header=0,usecols=[0,1,2],sheet_name=1,skiprows=[0,1])
# Out:
#           Columbo  Sri Lanka
# John
# Mandy     Canbera  Australia
# Parry     Toronto     Canada
# Tom    New Jersey        USA

# %%
teacher = pd.read_excel('exl.xlsx',index_col=0,header=0,usecols=[0,1,2],sheet_name=1)
print(teacher)
# Out:
#              City    Country
# Rahul      Mumbai      India
# John      Columbo  Sri Lanka
# Mandy     Canbera  Australia
# Parry     Toronto     Canada
# Tom    New Jersey        USA

# %%
teacher
# Out:
#              City    Country
# Rahul      Mumbai      India
# John      Columbo  Sri Lanka
# Mandy     Canbera  Australia
# Parry     Toronto     Canada
# Tom    New Jersey        USA

# %%
teacher.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Rahul to Tom
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     5 non-null      object
#  1   Country  5 non-null      object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
teacher.head()
# head() function displays first few rows and tail() displays last few rows
# Out:
#              City    Country
# Rahul      Mumbai      India
# John      Columbo  Sri Lanka
# Mandy     Canbera  Australia
# Parry     Toronto     Canada
# Tom    New Jersey        USA

# %%
teacher.to_csv("newCSV.csv")
